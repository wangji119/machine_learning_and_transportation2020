# %%
#Dataset1
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

column_names = ['RM','LSTAT','PTRATIO','MEDV']
data = pd.read_csv('C:\\Users\\administrater\\Desktop\\machinelearning\\machine-learning-master\\projects\\boston_housing\\housing.csv')
print("Boston housing dataset has {} data points with {} variables each.".format(*data.shape))
# Out:
# Boston housing dataset has 489 data points with 4 variables each.

# %%
data.head()
# Out:
#       RM  LSTAT  PTRATIO      MEDV
# 0  6.575   4.98     15.3  504000.0
# 1  6.421   9.14     17.8  453600.0
# 2  7.185   4.03     17.8  728700.0
# 3  6.998   2.94     18.7  701400.0
# 4  7.147   5.33     18.7  760200.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 489 entries, 0 to 488
# Data columns (total 4 columns):
# RM         489 non-null float64
# LSTAT      489 non-null float64
# PTRATIO    489 non-null float64
# MEDV       489 non-null float64
# dtypes: float64(4)
# memory usage: 15.4 KB

# %%
from sklearn.model_selection import train_test_split

X = data[column_names[0:-1]]
y = data[column_names[-1]]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2020)

# %%
#Standardization
from sklearn.preprocessing import StandardScaler

ss = StandardScaler()

X_train = ss.fit_transform(X_train)
X_test = ss.transform(X_test)

# %%
X_train
X_train.shape
# Out:
# (391, 3)

# %%
X_test.shape
# Out:
# (98, 3)

# %%
#method1: LinearRegression
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

lr = LinearRegression()
lr.fit(X_train, y_train)
lr_y_predict = lr.predict(X_test)
LinearRegression_score = r2_score(y_test, lr_y_predict)

#print (lr_y_predict)
#print (y_test)

print ('LinearRegression结果为：')
print ('%s: %f' %('MAE',mean_absolute_error(y_test, lr_y_predict)))
print ('%s: %f' %('MSE',mean_squared_error(y_test, lr_y_predict)))
print ('%s: %f' %('r2 score',LinearRegression_score))
# Out:
# LinearRegression结果为：
# MAE: 64456.496246
# MSE: 6922885233.555172
# r2 score: 0.706385

# %%
#method2: SVR
from sklearn.svm import SVR
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

svr = SVR(kernel='sigmoid')
#No matter how I set up the kernel function，such as 'sigmoid','linear','poly','rbf',etc. and the number of iterations, the r2 score is always
#the negative number.I've looked up the information and it indicates that setting the parameters to adjust the model yields a fit that is also 
#more erroneous than a random guess at a mean.
svr.fit(X_train, y_train)
svr_y_predict = svr.predict(X_test)
SVR_score = r2_score(y_test, svr_y_predict)

print ('SVR结果为：')
print ('%s: %f' %('MAE',mean_absolute_error(y_test, svr_y_predict)))
print ('%s: %f' %('MSE',mean_squared_error(y_test, svr_y_predict)))
print ('%s: %f' %('r2 score',SVR_score))
# Out:
# SVR结果为：
# MAE: 123101.190631
# MSE: 23744697050.013432
# r2 score: -0.007067

# %%
from sklearn.svm import SVR
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

svr = SVR(kernel='linear')
svr.fit(X_train, y_train)
svr_y_predict = svr.predict(X_test)
SVR_score = r2_score(y_test, svr_y_predict)

print ('SVR结果为：')
print ('%s: %f' %('MAE',mean_absolute_error(y_test, svr_y_predict)))
print ('%s: %f' %('MSE',mean_squared_error(y_test, svr_y_predict)))
print ('%s: %f' %('r2 score',SVR_score))
# Out:
# SVR结果为：
# MAE: 122837.131662
# MSE: 23649074830.101707
# r2 score: -0.003011

# %%
from sklearn.svm import SVR
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

svr = SVR(kernel='poly')
svr.fit(X_train, y_train)
svr_y_predict = svr.predict(X_test)
SVR_score = r2_score(y_test, svr_y_predict)

print ('SVR结果为：')
print ('%s: %f' %('MAE',mean_absolute_error(y_test, svr_y_predict)))
print ('%s: %f' %('MSE',mean_squared_error(y_test, svr_y_predict)))
print ('%s: %f' %('r2 score',SVR_score))
# Out:
# SVR结果为：
# MAE: 123008.905662
# MSE: 23686253724.468506
# r2 score: -0.004588

# %%
from sklearn.svm import SVR
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

svr = SVR(kernel='rbf')
svr.fit(X_train, y_train)
svr_y_predict = svr.predict(X_test)
SVR_score = r2_score(y_test, svr_y_predict)

print ('SVR结果为：')
print ('%s: %f' %('MAE',mean_absolute_error(y_test, svr_y_predict)))
print ('%s: %f' %('MSE',mean_squared_error(y_test, svr_y_predict)))
print ('%s: %f' %('r2 score',SVR_score))
# Out:
# SVR结果为：
# MAE: 123150.974580
# MSE: 23762683915.538269
# r2 score: -0.007830

# %%
#method3: KNeighborsRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

knr = KNeighborsRegressor()
knr.fit(X_train, y_train)
knr_y_predict = knr.predict(X_test)
KNeighborsRegressor_score = r2_score(y_test, knr_y_predict)

print ('KNeighborsRegressor结果为：')
print ('%s: %f' %('MAE',mean_absolute_error(y_test, knr_y_predict)))
print ('%s: %f' %('MSE',mean_squared_error(y_test, knr_y_predict)))
print ('%s: %f' %('r2 score',KNeighborsRegressor_score))
# Out:
# KNeighborsRegressor结果为：
# MAE: 50442.857143
# MSE: 4451202000.000000
# r2 score: 0.811214

# %%
#method4: DecisionTreeRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

dtr = DecisionTreeRegressor()
dtr.fit(X_train, y_train)
dtr_y_predict = dtr.predict(X_test)
DecisionTreeRegressor_score = r2_score(y_test, dtr_y_predict)

print ('DecisionTreeRegressor结果为：')
print ('%s: %f' %('MAE',mean_absolute_error(y_test, dtr_y_predict)))
print ('%s: %f' %('MSE',mean_squared_error(y_test, dtr_y_predict)))
print ('%s: %f' %('r2 score',DecisionTreeRegressor_score))
# Out:
# DecisionTreeRegressor结果为：
# MAE: 60771.428571
# MSE: 6450750000.000000
# r2 score: 0.726409

# %%
#method5: RandomForestRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

rfr = RandomForestRegressor()
rfr.fit(X_train, y_train)
rfr_y_predict = rfr.predict(X_test)
RandomForestRegressor_score = r2_score(y_test, rfr_y_predict)

print ('RandomForestRegressor结果为：')
print ('%s: %f' %('MAE',mean_absolute_error(y_test, rfr_y_predict)))
print ('%s: %f' %('MSE',mean_squared_error(y_test, rfr_y_predict)))
print ('%s: %f' %('r2 score',RandomForestRegressor_score))
# Out:
# RandomForestRegressor结果为：
# MAE: 51912.857143
# MSE: 4445757000.000000
# r2 score: 0.811445

# %%
#method6: GradientBoostingRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

gbr = GradientBoostingRegressor()
gbr.fit(X_train, y_train)
gbr_y_predict = gbr.predict(X_test)
GradientBoostingRegressor_score = r2_score(y_test, gbr_y_predict)

print ('GradientBoostingRegressor结果为：')
print ('%s: %f' %('MAE',mean_absolute_error(y_test, gbr_y_predict)))
print ('%s: %f' %('MSE',mean_squared_error(y_test, gbr_y_predict)))
print ('%s: %f' %('r2 score',GradientBoostingRegressor_score))
# Out:
# GradientBoostingRegressor结果为：
# MAE: 49367.449549
# MSE: 4128230712.017980
# r2 score: 0.824912

# %%
#method7: MLPRegressor
from sklearn.neural_network import MLPRegressor 
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

mlpr = MLPRegressor(hidden_layer_sizes=(200,10), max_iter=9000)
#If max_iter is too little,there is a convergence warning that means the not best fitting,and 9000 is the edge.
mlpr.fit(X_train, y_train)
mlpr_y_predict = mlpr.predict(X_test)
MLPRegressor_score = r2_score(y_test, mlpr_y_predict)

print ('MLPRegressor结果为：')
print ('%s: %f' %('MAE',mean_absolute_error(y_test, mlpr_y_predict)))
print ('%s: %f' %('MSE',mean_squared_error(y_test, mlpr_y_predict)))
print ('%s: %f' %('r2 score',MLPRegressor_score))
# Out:
# MLPRegressor结果为：
# MAE: 52696.899602
# MSE: 5068968177.072384
# r2 score: 0.785013

# %%
#The bar graph
plt.figure(figsize=(10, 10), dpi=80)
Number = 7
values = (LinearRegression_score,SVR_score,KNeighborsRegressor_score,DecisionTreeRegressor_score,RandomForestRegressor_score,
          GradientBoostingRegressor_score,MLPRegressor_score)
index = np.arange(Number)
width = 0.45
p2 = plt.bar(index, values, width, label="r2 score", color="#87CEFA")
plt.xlabel('method')
plt.title('The score of prediction using following methods')
plt.xticks(index, ('LR', 'SVR', 'KNR', 'DTR', 'RFR', 'GBR', 'MLPR'))
plt.legend(loc="upper right")
plt.show()

# %%
#The predicted and actual value
plt.figure(figsize=(20,20))
x = np.linspace(0,98,98)
y0 = y_test
y1 = lr_y_predict
y2 = svr_y_predict
y3 = knr_y_predict
y4 = dtr_y_predict
y5 = rfr_y_predict
y6 = gbr_y_predict
y7 = mlpr_y_predict


plt.subplot(4,2,1)
plt.title('LR')
plt.plot(x,y1,color='orange',linewidth=1)
plt.plot(x,y0,color='red',linewidth=1,linestyle='--')

plt.subplot(4,2,2)
plt.title('SVR')
plt.plot(x,y2,color='yellow',linewidth=1)
plt.plot(x,y0,color='red',linewidth=1,linestyle='--')

plt.subplot(4,2,3)
plt.title('KNR')
plt.plot(x,y3,color='green',linewidth=1)
plt.plot(x,y0,color='red',linewidth=1,linestyle='--')

plt.subplot(4,2,4)
plt.title('DTR')
plt.plot(x,y4,color='blue',linewidth=1)
plt.plot(x,y0,color='red',linewidth=1,linestyle='--')

plt.subplot(4,2,5)
plt.title('RFR')
plt.plot(x,y5,color='purple',linewidth=1)
plt.plot(x,y0,color='red',linewidth=1,linestyle='--')

plt.subplot(4,2,6)
plt.title('GBR')
plt.plot(x,y6,color='black',linewidth=1)
plt.plot(x,y0,color='red',linewidth=1,linestyle='--')

plt.subplot(4,2,7)
plt.title('MLPR')
plt.plot(x,y7,color='grey',linewidth=1)
plt.plot(x,y0,color='red',linewidth=1,linestyle='--')


plt.subplots_adjust(wspace =0.5, hspace =0.95)

plt.show()

# %%
#Dataset2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

column2_names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
data = pd.read_csv('C:\\Users\\administrater\\Desktop\\machinelearning\\DIY_ML_Systems_with_Python_2nd_Edition-master\\Chapter_2\\datasets\\boston-house\\housing.data', delim_whitespace=True, names=column2_names)
print("Boston housing dataset has {} data points with {} variables each.".format(*data.shape))
# Out:
# Boston housing dataset has 506 data points with 14 variables each.

# %%
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
# CRIM       506 non-null float64
# ZN         506 non-null float64
# INDUS      506 non-null float64
# CHAS       506 non-null int64
# NOX        506 non-null float64
# RM         506 non-null float64
# AGE        506 non-null float64
# DIS        506 non-null float64
# RAD        506 non-null int64
# TAX        506 non-null float64
# PTRATIO    506 non-null float64
# B          506 non-null float64
# LSTAT      506 non-null float64
# MEDV       506 non-null float64
# dtypes: float64(12), int64(2)
# memory usage: 55.4 KB

# %%
from sklearn.model_selection import train_test_split

X = data[column2_names[0:-1]]
y = data[column2_names[-1]]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2020)

# %%
#Standardization
from sklearn.preprocessing import StandardScaler

ss = StandardScaler()

X_train = ss.fit_transform(X_train)
X_test = ss.transform(X_test)

# %%
X_train
X_train.shape
# Out:
# (404, 13)

# %%
X_test.shape
# Out:
# (102, 13)

# %%
#method1: LinearRegression
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

lr = LinearRegression()
lr.fit(X_train, y_train)
lr2_y_predict = lr.predict(X_test)
LinearRegression_score = r2_score(y_test, lr2_y_predict)

print (lr2_y_predict)
print (y_test)

print ('LinearRegression结果为：')
print ('%s: %f' %('MAE',mean_absolute_error(y_test, lr2_y_predict)))
print ('%s: %f' %('MSE',mean_squared_error(y_test, lr2_y_predict)))
print ('%s: %f' %('r2 score',LinearRegression_score))
# Out:
# [20.00101515 20.28791996 11.01110241 30.96363775 25.10775846 18.29968819
#  22.34584907 25.53119837 16.96133139 27.41721052 31.32722599 14.1892731
#  23.17566495 40.16731102 14.49409236 20.78246771 13.28406375 25.62698695
#  20.16197915 21.36932737 17.45976865 31.45637476 17.72944877 27.24873378
#   6.64787399  6.50259753 25.69001089 16.27186452 32.9098371  14.64485892
#  26.59272781 27.89402778 -4.19547078 23.85639883 19.20707293 19.71945987
#  25.34683481 20.98826507 23.04293937 13.90991899 26.31233834 22.40006257
#   9.0153142  34.52580383 25.7370247  19.11759034 20.45014258 13.68798012
#  24.80753665 30.9571743  32.3927216  27.14775914 19.97213546 11.97152171
#  16.39737432 18.36206545 28.61296585 13.62799241 10.1407046  27.68208063
#  25.48464464 22.4867408  27.68541058 43.26026554 35.70072891 25.47447112
#  22.84682975  8.01771253 13.01416473 18.80377499 25.93535402 22.01016823
#  30.74701007 17.95628127 23.0556497  21.02251114 21.74926613 25.221932
#  25.5575675  32.36163407 22.50259045 12.28366034 32.74635154 37.06581088
#  34.52871439 12.11517708 20.58097239 20.6961353  30.81266616 18.63845986
#  18.34720964 18.48561998 22.22870508 17.19923432 20.45175059 21.72821686
#  14.77967756 43.16671877 16.98263964 16.69579533 11.85610098 26.14711863]
# 409    27.5
# 247    20.5
# 399     6.3
# 300    24.8
# 321    23.1
# 31     14.5
# 342    16.5
# 375    15.0
# 379    10.2
# 288    22.3
# 229    31.5
# 129    14.3
# 208    24.4
# 162    50.0
# 428    11.0
# 110    21.7
# 429     9.5
# 314    23.8
# 331    17.1
# 483    21.8
# 135    18.1
# 39     30.8
# 316    17.8
# 287    23.2
# 398     5.0
# 388    10.2
# 74     24.1
# 434    11.7
# 237    31.5
# 380    10.4
#        ...
# 175    29.4
# 207    22.5
# 76     20.0
# 12     21.7
# 432    16.1
# 56     24.7
# 66     19.4
# 369    50.0
# 502    20.6
# 445    11.8
# 220    26.7
# 261    43.1
# 189    34.9
# 145    13.8
# 122    20.5
# 113    18.7
# 2      34.7
# 381    10.9
# 421    14.2
# 499    17.5
# 45     19.3
# 106    19.5
# 336    19.5
# 248    24.5
# 424    11.7
# 204    50.0
# 495    23.1
# 244    17.6
# 413    16.3
# 216    23.3
# Name: MEDV, Length: 102, dtype: float64
# LinearRegression结果为：
# MAE: 3.369037
# MSE: 19.773992
# r2 score: 0.768270

# %%
#method2: SVR
from sklearn.svm import SVR
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

svr = SVR(kernel='sigmoid')
svr.fit(X_train, y_train)
svr21_y_predict = svr.predict(X_test)
SVRsigmoid_score = r2_score(y_test, svr21_y_predict)

print ('SVRsigmoid结果为：')
print ('%s: %f' %('MAE',mean_absolute_error(y_test, svr21_y_predict)))
print ('%s: %f' %('MSE',mean_squared_error(y_test, svr21_y_predict)))
print ('%s: %f' %('r2 score',SVRsigmoid_score))
# Out:
# SVRsigmoid结果为：
# MAE: 4.188697
# MSE: 35.839710
# r2 score: 0.579997

# %%
from sklearn.svm import SVR
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

svr = SVR(kernel='poly')
svr.fit(X_train, y_train)
svr22_y_predict = svr.predict(X_test)
SVRpoly_score = r2_score(y_test, svr22_y_predict)

print ('SVRpoly结果为：')
print ('%s: %f' %('MAE',mean_absolute_error(y_test, svr22_y_predict)))
print ('%s: %f' %('MSE',mean_squared_error(y_test, svr22_y_predict)))
print ('%s: %f' %('r2 score',SVRpoly_score))
# Out:
# SVRpoly结果为：
# MAE: 3.232939
# MSE: 21.295807
# r2 score: 0.750436

# %%
from sklearn.svm import SVR
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

svr = SVR(kernel='linear')
svr.fit(X_train, y_train)
svr23_y_predict = svr.predict(X_test)
SVRlinear_score = r2_score(y_test, svr23_y_predict)

print ('SVRlinear结果为：')
print ('%s: %f' %('MAE',mean_absolute_error(y_test, svr23_y_predict)))
print ('%s: %f' %('MSE',mean_squared_error(y_test, svr23_y_predict)))
print ('%s: %f' %('r2 score',SVRlinear_score))
# Out:
# SVRlinear结果为：
# MAE: 3.276773
# MSE: 22.590114
# r2 score: 0.735268

# %%
from sklearn.svm import SVR
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

svr = SVR(kernel='rbf')
svr.fit(X_train, y_train)
svr24_y_predict = svr.predict(X_test)
SVRrbf_score = r2_score(y_test, svr24_y_predict)

print ('SVRrbf结果为：')
print ('%s: %f' %('MAE',mean_absolute_error(y_test, svr24_y_predict)))
print ('%s: %f' %('MSE',mean_squared_error(y_test, svr24_y_predict)))
print ('%s: %f' %('r2 score',SVRrbf_score))
# Out:
# SVRrbf结果为：
# MAE: 3.344833
# MSE: 31.481933
# r2 score: 0.631065

# %%
#method3: KNeighborsRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

knr = KNeighborsRegressor()
knr.fit(X_train, y_train)
knr2_y_predict = knr.predict(X_test)
KNeighborsRegressor_score = r2_score(y_test, knr2_y_predict)

print ('KNeighborsRegressor结果为：')
print ('%s: %f' %('MAE',mean_absolute_error(y_test, knr2_y_predict)))
print ('%s: %f' %('MSE',mean_squared_error(y_test, knr2_y_predict)))
print ('%s: %f' %('r2 score',KNeighborsRegressor_score))
# Out:
# KNeighborsRegressor结果为：
# MAE: 2.646863
# MSE: 17.506945
# r2 score: 0.794837

# %%
#method4: DecisionTreeRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

dtr = DecisionTreeRegressor()
dtr.fit(X_train, y_train)
dtr2_y_predict = dtr.predict(X_test)
DecisionTreeRegressor_score = r2_score(y_test, dtr2_y_predict)

print ('DecisionTreeRegressor结果为：')
print ('%s: %f' %('MAE',mean_absolute_error(y_test, dtr2_y_predict)))
print ('%s: %f' %('MSE',mean_squared_error(y_test, dtr2_y_predict)))
print ('%s: %f' %('r2 score',DecisionTreeRegressor_score))
# Out:
# DecisionTreeRegressor结果为：
# MAE: 3.462745
# MSE: 40.685686
# r2 score: 0.523207

# %%
#method5: RandomForestRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

rfr = RandomForestRegressor()
rfr.fit(X_train, y_train)
rfr2_y_predict = rfr.predict(X_test)
RandomForestRegressor_score = r2_score(y_test, rfr2_y_predict)

print ('RandomForestRegressor结果为：')
print ('%s: %f' %('MAE',mean_absolute_error(y_test, rfr2_y_predict)))
print ('%s: %f' %('MSE',mean_squared_error(y_test, rfr2_y_predict)))
print ('%s: %f' %('r2 score',RandomForestRegressor_score))
# Out:
# C:\Users\administrater\Anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# RandomForestRegressor结果为：
# MAE: 2.932255
# MSE: 18.594734
# r2 score: 0.782090

# %%
#method6: GradientBoostingRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

gbr = GradientBoostingRegressor()
gbr.fit(X_train, y_train)
gbr2_y_predict = gbr.predict(X_test)
GradientBoostingRegressor_score = r2_score(y_test, gbr2_y_predict)

print ('GradientBoostingRegressor结果为：')
print ('%s: %f' %('MAE',mean_absolute_error(y_test, gbr2_y_predict)))
print ('%s: %f' %('MSE',mean_squared_error(y_test, gbr2_y_predict)))
print ('%s: %f' %('r2 score',GradientBoostingRegressor_score))
# Out:
# GradientBoostingRegressor结果为：
# MAE: 2.427927
# MSE: 12.975863
# r2 score: 0.847937

# %%
#method7: MLPRegressor
from sklearn.neural_network import MLPRegressor 
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

mlpr = MLPRegressor(hidden_layer_sizes=(200,10), max_iter=9000)
#If max_iter is too little,there is a convergence warning that means the not best fitting,and 9000 is the edge.
mlpr.fit(X_train, y_train)
mlpr2_y_predict = mlpr.predict(X_test)
MLPRegressor_score = r2_score(y_test, mlpr2_y_predict)

print ('MLPRegressor结果为：')
print ('%s: %f' %('MAE',mean_absolute_error(y_test, mlpr2_y_predict)))
print ('%s: %f' %('MSE',mean_squared_error(y_test, mlpr2_y_predict)))
print ('%s: %f' %('r2 score',MLPRegressor_score))
# Out:
# MLPRegressor结果为：
# MAE: 3.426072
# MSE: 20.637807
# r2 score: 0.758147

# %%
#The bar graph
plt.figure(figsize=(10, 10), dpi=80)
Number = 10
values = (LinearRegression_score,SVRsigmoid_score,SVRpoly_score,SVRlinear_score,SVRrbf_score,
          KNeighborsRegressor_score,DecisionTreeRegressor_score,RandomForestRegressor_score,
          GradientBoostingRegressor_score,MLPRegressor_score)
index = np.arange(Number)
width = 0.3
p2 = plt.bar(index, values, width, label="r2 score")
plt.xlabel('method')
plt.title('The score of prediction using following methods')
plt.xticks(index, ('LR', 'SVRsigmoid','SVRpoly','SVRlinear','SVRrbf', 'KNR', 'DTR', 'RFR', 'GBR', 'MLPR'))
plt.legend(loc="upper right")
plt.show()

# %%
#The predicted and actual value
plt.figure(figsize=(20, 20))
x = np.linspace(0,102,102)
y0 = y_test
y1 = lr2_y_predict
y2 = svr21_y_predict
y3 = svr22_y_predict
y4 = svr23_y_predict
y5 = svr24_y_predict
y6 = knr2_y_predict
y7 = dtr2_y_predict
y8 = rfr2_y_predict
y9 = gbr2_y_predict
y10 = mlpr2_y_predict


plt.subplot(5,2,1)
plt.title('LR')
plt.plot(x,y1,color='orange',linewidth=1)
plt.plot(x,y0,color='red',linewidth=1,linestyle='--')

plt.subplot(5,2,2)
plt.title('SVRsigmoid')
plt.plot(x,y2,color='yellow',linewidth=1)
plt.plot(x,y0,color='red',linewidth=1,linestyle='--')

plt.subplot(5,2,3)
plt.title('SVRpoly')
plt.plot(x,y3,color='yellow',linewidth=1)
plt.plot(x,y0,color='red',linewidth=1,linestyle='--')

plt.subplot(5,2,4)
plt.title('SVRlinear')
plt.plot(x,y4,color='yellow',linewidth=1)
plt.plot(x,y0,color='red',linewidth=1,linestyle='--')

plt.subplot(5,2,5)
plt.title('SVRrbf')
plt.plot(x,y5,color='yellow',linewidth=1)
plt.plot(x,y0,color='red',linewidth=1,linestyle='--')

plt.subplot(5,2,6)
plt.title('KNR')
plt.plot(x,y6,color='black',linewidth=1)
plt.plot(x,y0,color='red',linewidth=1,linestyle='--')

plt.subplot(5,2,7)
plt.title('DTR')
plt.plot(x,y7,color='grey',linewidth=1)
plt.plot(x,y0,color='red',linewidth=1,linestyle='--')

plt.subplot(5,2,8)
plt.title('RFR')
plt.plot(x,y7,color='green',linewidth=1)
plt.plot(x,y0,color='red',linewidth=1,linestyle='--')

plt.subplot(5,2,9)
plt.title('GBR')
plt.plot(x,y7,color='blue',linewidth=1)
plt.plot(x,y0,color='red',linewidth=1,linestyle='--')

plt.subplot(5,2,10)
plt.title('MLPR')
plt.plot(x,y7,color='purple',linewidth=1)
plt.plot(x,y0,color='red',linewidth=1,linestyle='--')

plt.subplots_adjust(wspace =0.4, hspace =0.95)

plt.show()
